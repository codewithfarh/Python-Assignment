# %% [markdown]
# QUESTION 1: Working with Lists
# 1.	Create a list called numbers containing at least 8 integers.
# 2.	Using a for loop, do the following:
# o	Print all numbers in the list.
# o	Print the sum of all numbers.
# o	Print only the even numbers.

# %% [markdown]
# Requirements:
# •	Use at least one loop.
# •	Use conditional statements.
# •	Display clear output.

# %%
# write here code.
nums = [20,34,56,67,54,33,22,11]

total_sum = 0

for n in nums:
    print(f"the number is :", n)
    total_sum = total_sum + n

    if n % 2 == 0:
        print(f"even numbers :", n)
       


print(f"the sum of all numbers is :", {total_sum})
# Out:
# the number is : 20
# even numbers : 20
# the number is : 34
# even numbers : 34
# the number is : 56
# even numbers : 56
# the number is : 67
# the number is : 54
# even numbers : 54
# the number is : 33
# the number is : 22
# even numbers : 22
# the number is : 11
# the sum of all numbers is : {297}

# %% [markdown]
# QUESTION 2: Dictionary Basics
# 1.	Create a dictionary called student with the following keys:
# o	name
# o	age
# o	course
# o	marks (must store a list of 3 marks)
# 2.	Using loops:
# o	Print all keys and their values.
# o	Calculate the average of the marks.
# o	Display whether the student Passed (average ≥ 50) or Failed.
# Requirements:
# •	Dictionary must contain a list.
# •	Use loops to calculate the average.

# %%
# write code here.
student = { "name" :"anum",
           "age" : 32,
           "course" :"python",
           "marks" :[80,90,78,],
           }

for keys,values in student.items():
    print(f"here is keys :{keys} and values : {values}")

total = 0

for i in student["marks"]:
    total = total + i

    average = total/ len(student["marks"])


print(f"the average is :", {average})

if average >= 50:
        print("you are passed")

else:
        print("you are failed")
# Out:
# here is keys :name and values : anum
# here is keys :age and values : 32
# here is keys :course and values : python
# here is keys :marks and values : [80, 90, 78]
# the average is : {82.66666666666667}
# you are passed

# %% [markdown]
# QUESTION 3: List of Dictionaries
# 1.	Create a list called employees.
# 2.	Each employee must be stored as a dictionary containing:
# o	name
# o	department
# o	salary
# 3.	Using loops:
# o	Print details of all employees.
# o	Find the employee with the highest salary.
# o	Calculate the total salary expense.
# Requirements:
# •	Minimum 3 employees.
# •	Use comparison logic.
# •	Use loops to process data.

# %%
# write code here.
employees = [
        {"name" : "Hassan",
         "department" : "cleaning",
         "salary" : 20000},
        {"name" : "Ammar",
         "department" : "maintainance",
         "salary" : 40000},  
        {"name" : "Fawad",
         "department" : "service",
         "salary" : 50000},
]

highest_paid_emp = employees[0]

for emp in employees:
    if emp["salary"] > highest_paid_emp ["salary"]:

        highest_paid_emp = emp

print("-------details------")
print(f"The highest salary employ name is : {highest_paid_emp['name']}")
print(f"Tthe highest salary is : {highest_paid_emp['salary']} ")


total_expense = 0 

for emp in employees:

    total_expense += emp ["salary"]


print("------claculate salary expense--------")
print(f"The total expense is : {total_expense}")
print("--------")
# Out:
# -------details------
# The highest salary employ name is : Fawad
# Tthe highest salary is : 50000
# ------claculate salary expense--------
# The total expense is : 110000
# --------

# %% [markdown]
# QUESTION 4: While Loop with User Input
# 1.	Ask the user to enter numbers.
# 2.	Store the numbers in a list.
# 3.	Stop when the user enters -1.
# 4.	After the loop ends:
# o	Print the complete list.
# o	Print the largest number.
# o	Print the smallest number.
# Requirements:
# •	Must use a while loop.
# •	Must store input in a list.
# •	Handle user input correctly.

# %%
# write code.
my_list = []

print("<---welcome to the list--->")

while True:
    value = int(input("enter value :"))

    if value == -1:
        break

    my_list.append(value)

    max_val = max(my_list)
    min_val = min(my_list)

print(f"here is the list :", my_list)
print(f"The largest number is : ",max_val )
print(f"The smallest number is :",min_val)
print(f"---------")
# Out:
# <---welcome to the list--->
# here is the list : [23, 45, 67, 87, 98, 66, 44, 33, 90]
# The largest number is :  98
# The smallest number is : 23
# ---------

# %% [markdown]
# QUESTION 5: Word Frequency Counter
# 1.	Ask the user to enter a sentence.
# 2.	Convert the sentence into a list of words.
# 3.	Use a dictionary to count how many times each word appears.
# 4.	Print the word frequency clearly.
# Example Format (for understanding only):
# apple: 3
# banana: 2
# orange: 1
# Requirements:
# •	Use string splitting.
# •	Use a dictionary for counting.
# •	Use loops for processing.

# %%
# write code here.
sentence = input("enter sentence :")

word = sentence.split()

frequency = {}

for i in word:
    if i in frequency:
        frequency[i] = frequency[i] +1

    else :
        frequency [i] = 1
    
print(frequency)
print(f"The frequeny of all word is : ",frequency)
# Out:
# {'biscuit': 4, 'toffee': 5, 'chocolate': 4}
# The frequeny of all word is :  {'biscuit': 4, 'toffee': 5, 'chocolate': 4}

# %% [markdown]
# QUESTION 6: Nested Loops – Multiplication Table
# Using nested loops, print a multiplication table from 1 to 5.
# Expected Output Format:
# 1 2 3 4 5
# 2 4 6 8 10
# 3 6 9 12 15
# 4 8 12 16 20
# 5 10 15 20 25
# Requirements:
# •	Must use nested loops.
# •	Proper formatting required.

# %%
# write code here.

for i in range(1, 6):
    for j in range (1, 6):
        print(i * j , end=" ")

    print()

print(f"The multiplication table is created.")
# Out:
# 1 2 3 4 5
# 2 4 6 8 10
# 3 6 9 12 15
# 4 8 12 16 20
# 5 10 15 20 25
# The multiplication table is created.

# %% [markdown]
# General Requirements
# •	Use:
# o	At least 2 lists
# o	At least 2 dictionaries
# o	At least 3 loops
# o	At least 1 nested loop
# •	Include comments explaining your code.
# •	Proper indentation is required.
# •	Code must run without errors.
# •	Submit your .py file before the due date.
