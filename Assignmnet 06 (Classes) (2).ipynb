# %% [markdown]
# 1. Write a Python program to create a class representing a Circle. Include methods to calculate its area and perimeter.

# %%
# Add your code here

class Circle:
    def __init__(self,radius,pi):
        self.radius = radius
        self.pi = 3.14
    

    def calculate_area(self):
        area =  self.pi *(self.radius **2 )

        print(f"The area of a circle is :{area}")


    def calculate_perimeter(self):
        perimeter = 2 * self.pi * self.radius

        print(f"The perimeter of a circle is : {perimeter}")


i = float(input("enter value :"))

result = Circle(i, 3.14)

result.calculate_area()
result.calculate_perimeter()
# Out:
# The area of a circle is :6217.985000000001
# The perimeter of a circle is : 279.46000000000004

# %% [markdown]
# 2. Write a Python program to create a person class. Include attributes like name, country and date of birth. Implement a method to determine the person's age.

# %%
# Add your code here
class Person:
    def __init__(self,name,country,birth_year):
        self.name = name
        self.country = country 
        self.birth_year = birth_year

    def find_age(self):
        current_year = 2026   ###let's assume
        age = current_year - self.birth_year

        print(f"Name is : {self.name}")
        print(f"country : {self.country}")
        print(f"your age is : {age}")
        

# let' call function.

user = Person("Bilal", "karachi", 2000)

user.find_age()
# Out:
# Name is : Bilal
# country : karachi
# your age is : 26

# %% [markdown]
# 3. Write a Python program to create a calculator class. Include methods for basic arithmetic operations.

# %%
# Add your code here
class Calculator:
    def __init__(self,num1, num2):
        self.num1 = num1
        self.num2 = num2

    def addition(self):
        sum = self.num1 + self.num2
        print(f"the addition result is : {self.num1 + self.num2}")

    def subtraction(self):
        diff = self.num1 - self.num2
        print(f"the subtraction result is : {self.num1 - self.num2}")

    def multiplication(self):
            multiply = self.num1 * self.num2
            print(f"the multiplication result is : {self.num1 * self.num2}")

    def division (self):
            if self.num2 != 0:
                print(f"the result of division is : {self.num1 / self.num2}")

            else:
                print("the number is not divisible by 0")


i = float(input("enter your value :"))
operator = input("enter operator (+,-,*,/)")
j = float(input("enter your value :"))


s1 = Calculator(i , j)
if operator == "+":
    s1.addition()
elif operator == "-":
    s1.subtraction()
elif operator == "*":
    s1.multiplication()
elif operator == "/":
    s1.division()
else:
    print("invalid number")
# Out:
# the result of division is : 58.5
