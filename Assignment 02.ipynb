# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#Type your code here
salary  = float(input("enter your amount"))
years_of_service = int(input("enter your service years"))

if years_of_service > 5:
    bonus = salary * 0.05
    print(f"you are applicable of bonus : {bonus}")
else :
    print(f"you are not applicable of bonus")
# Out:
# you are applicable of bonus : 2500.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
#Type your code here
age_str = input("Enter your age")
age = int(age_str) 

if age > 17:
    print ("you are eligible for cast vote")
else : 
    print ("you are not eligible")
# Out:
# you are eligible for cast vote

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
#Type your code here
num_str = int(input("enter your number"))
type(num_str)

if num_str % 2 ==0:
    print(f"even number")
else:
    print("odd number")
# Out:
# odd number

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
#Type your code here
number = int(input("enter your number"))

if number % 7 ==0:
    print(f"{number} is divisible by 7")
else:
    print(f"{number} is not divisvible by 7 ")
# Out:
# 79 is not divisvible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Type your code here
num = int (input( "enter a number"))

if num % 5 == 0:
    print("'hello'")
else:
    print ("'bye'")
# Out:
# 'bye'

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
#Type your code here
number = 568
last_digit = 568 % 10

print (f" {last_digit} is the last digit of a number")
# Out:
#  8 is the last digit of a number

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#Type your code here 
length = int(input("enter value"))
breadth = int(input("enter value"))

if length ==breadth:
    print(f" your value : square")
else :
    print(f" your value : rectangle")
# Out:
#  your value : rectangle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
# Type your code here
num_1 =int(input("enter a number"))
num_2 =int(input("enter a number"))

if num_1 > num_2:
    print(f" {num_1} is greater than value of : {num_2}")
else:
    print(f" {num_2} is lesser than {num_1}")
# Out:
#  400 is greater than value of : 350

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
#Type your code here
quantity = int(input("enter your quantity :"))
bill = quantity * 100

if bill > 1000:
    bill = bill * 0.90 
    print (" congratulations! you have won a 10% discount.")

else :
    print(" sorry! you have no discount.")
# Out:
#  congratulations! you have won a 10% discount.

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
#Type your code here
student_marks = int(input("enter your number"))


if student_marks >80 <100:
    print("'Grade A'")
elif student_marks >60 <80:
    print("'Grade B'")
elif student_marks >50 <60:
    print("'Grade C'")
elif student_marks >45 <50:
    print("'Grade D'")
elif student_marks >25 <45:
    print("'Grade E'")
else:
    print("'Grade F'")
# Out:
# 'Grade B'

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
#Type your code here
class_attendence=int(input("enter class attendence :"))
total_classes = int(input("enter total number of class"))

#percentage....
var_of_attendence = (class_attendence / total_classes)* 100

if var_of_attendence <75:
    print(f" {var_of_attendence} less than 75% you are not able to sit in class")
    print (f"you are not able to give exams")
else:
    print(f"{var_of_attendence} is greater than 75% you are allow to sit in class and give exam")
# Out:
#  50.0 less than 75% you are not able to sit in class
# you are not able to give exams

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
#Type your code here
gender = input( "male / female")
medical_cause = input("yes / no")

if gender== "female" and medical_cause=="yes":
    print(f" get some rest ")
elif gender== "male" and medical_cause =="no":
    print (f" you are able to sit in class")
else :
    print (f" you are not allowed for exams")
# Out:
#  you are not allowed for exams

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
#Type your code here
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Leap Year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here
age = int(input("enter your age"))
gender = input("male / female :")
marital_status = input("married / unmarried :")

if gender== "female":
    print (f"she will work only in urban areas")
elif gender== "male" and age >20 <40:
    print (f"he will work in anywhere")
elif gender=="male" and age >40 <60:
    print (f"he will work only in urban areas")
else :
    print(f"'error'")
# Out:
# he will work in anywhere

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
#Type your code here
person_1 = int(input("enter person1 age :"))
person_2 = int(input("enter person2 age"))
person_3 = int(input("enter person3 age"))

age = [person_1, person_2, person_3]

final_age = max(age)
final_age = min(age)

print( f" {max(age)} is the oldest person of aur family")
print( f"{min (age)} is the youngest person of our family")
# Out:
#  87 is the oldest person of aur family
# 22 is the youngest person of our family
